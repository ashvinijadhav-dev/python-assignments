# %% [markdown]
# # Jadhav Ashvini Manohar

# %% [markdown]
# ***1.Write a program to check if a number entered by the user is even or odd.***

# %%
number = int(input("Enter the number :"))

if number % 2==0:
    
    print("the number is even")
else:
    print("the number is odd")
# Out:
# Enter the number : 10
# the number is even

# %% [markdown]
# ***2.Write a program to check whether a number is positive, negative, or zero.***

# %%
num = float(input("Enter the number:"))

if num >0:
    
    print('you gave a positive number')
elif num < 0:
    print('you gave a negative number')
    
else:
    print('zero')
# Out:
# Enter the number: -12
# you gave a negative number

# %% [markdown]
# **3.Write a program that takes two numbers and prints the larger one.**

# %%
num1 = int(input('Enter the value for n1 :'))
num2 = int(input('Enter the value for n2 :'))

if num1 > num2:

    print(num1,' is larger')
else:
    print(num2, 'is larger')
# Out:
# Enter the value for n1 : 39
# Enter the value for n2 : 45
# 45 is larger

# %% [markdown]
# ***4.Ask the user to enter their age and check if they are eligible to vote (age >= 18).***

# %%
age = int(input("enter your age :"))

if age >= 18:
    
    print("you are eligible for vote")
else:
    print("you are not eligible for vote")
# Out:
# enter your age : 15
# you are not eligible for vote

# %% [markdown]
# ***5.Check if a number is divisible by both 5 and 11.***

# %%
num = int(input('Enter the number :'))

if num % 5 == 0 and num % 11 == 0:
    
    print(f'{num} is divisible by both 5 and 11')
else:
    print(f'{num} is not divisible by both 5 and 11')
# Out:
# Enter the number : 34
# 34 is not divisible by both 5 and 11

# %% [markdown]
# ***6.Check if a number is divisible by both 3 and 5.***

# %%
num1 = int(input('Enter the number:'))

if num1 % 3 == 0 and num1 % 5 == 0:

     print(f'{num1} is divisible by both 3 and 5')
else:
    print(f'{num1} is not divisible by both 3 and 5')
# Out:
# Enter the number: 10
# 10 is not divisible by both 3 and 5
